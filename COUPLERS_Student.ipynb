# %% [markdown]
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/05/logo-upv-horizontal.png)
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/06/logos-perte-chip-1024x119.png)
#
#
# # Laboratory 2.0. Coupler Design

# %% [markdown]
# ## 0. Imports

# %% [markdown]
# ### 0.1. General libraries

# %% [markdown]
# **Run only the first time you execute this Jupyter Notebook**
# You can delete this command lines after succesfully installing this tools

# %%
#!sudo apt-get install libgomp1
#!sudo apt-get install libxft2
#!sudo apt-get install libglu1

# %% [markdown]
# Run everytime you start to execute this Jupyter Notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

import tidy3d as td
import gplugins.tidy3d as gt

nm = 1e-3
wavelength = np.linspace(1500, 1600) * nm
f = td.C_0 / wavelength

# %% [markdown]
# ### 0.2. Functions by us

# %%
from upvfab_design_tools import MMI_EME, DC_EME

# %% [markdown]
# ## LO.1. Directional coupler cross-section in GDSFactory
#
# ### 1.1. Materials

# %%
nitride_complex = td.material_library["Si3N4"]["Luke2015PMLStable"].eps_model(f)
nitride_index, nitride_k = td.Medium.eps_complex_to_nk(nitride_complex)
box_complex = td.material_library["SiO2"]["Horiba"].eps_model(f)
box_index, box_k = td.Medium.eps_complex_to_nk(box_complex)

# %% [markdown]
# ### 1.2. Cross-Section Definition
#
# In GDSFactory - Tidy3d modesolver we have another function to easily define the Cross-Section of a Directional Coupler: [gt.modes.WaveguideCoupler()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.WaveguideCoupler.html). It implements the deep (rib) and shallow (ridge) directional coupler waveguides cross-section, using as input parameters all the dimensions of the waveguide cores and also the distance between them (gap).

# %%
lambda_c = 1.55

dcoupler_cs = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(1.2, 1.2), # Waveguide width
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness=300 * nm, # Waveguide height 
    gap=600 * nm,
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)

dcoupler_cs.plot_index()

# %% [markdown]
# ### 1.3. Simulations
#
# #### 1.3.1. Parameters
#
# As before, we can calculate the effective index (n_eff), TE and TM fraction for this cross-section using the already implemented class methods: .n_eff, .fraction_te and .fraction_tm. Remember that we will calculate one effective index for each mode (up to num_modes)

# %%
dcoupler_neff = dcoupler_cs.n_eff
print(dcoupler_neff)
# Out:
# 2026-04-28 12:20:55.380 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cbc1bb971a882eda.npz.
# [1.60942484+1.02849974e-04j 1.60116589+9.83178135e-05j
#  1.53540293+1.77367472e-04j 1.52057329+1.77190584e-04j]

# %%
dcoupler_cs.fraction_te
# Out:
# array([0.994898  , 0.99527537, 0.00888064, 0.01130183])

# %%
dcoupler_cs.fraction_tm
# Out:
# array([0.005102  , 0.00472463, 0.99111936, 0.98869817])

# %% [markdown]
# #### 1.3.2. Plots
#
# We could also plot the fields for each mode identified. Remember: the 'Ex' field component corresponds to TE modes, while the 'Ey' field component corresponds to TM modes. In the case of the directional coupler, the even and odd modes play a key role in facilitating energy exchange between the waveguides. Now, let's plot and analyze their behavior.

# %%
dcoupler_cs.plot_field(mode_index=0 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)
) #

# %%
dcoupler_cs.plot_field(mode_index=1 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
dcoupler_cs.plot_field(mode_index=2 , # Mode to be plotted
                          field_name='Ey', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
dcoupler_cs.plot_field(mode_index=3, # Mode to be plotted
                          field_name='Ey', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %% [markdown]
# #### 1.3.3. Beating or Coupling Length calculation (𝐿𝜋)
#
# The key parameter that determines the design of a directional coupler is the coupling or beating length. This length defines the total size of the coupling region required to transfer all the optical power from one waveguide to another. It is determined by the difference between the effective indices of the cross-section's odd and even modes:

# %%
# TE Modes: Modes 0 & 1
L_pi_TE = 0.5*lambda_c/(dcoupler_neff[0].real-dcoupler_neff[1].real)
print(L_pi_TE)

L_pi_TM =  0.5*lambda_c/(dcoupler_neff[2].real-dcoupler_neff[3].real)
print(L_pi_TM)
# Out:
# 93.83767536700753
# 52.26022367744142

# %% [markdown]
# GDSFactory has its own method implemented to calculate the coupling length: [.coupling_length()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.WaveguideCoupler.html)

# %%
dcoupler_cs.coupling_length()
# Out:
# array([93.83767537, 52.26022368])

# %% [markdown]
# ## LO.2. Directional coupler length and coupling coefficient
#
# The total power transferred to the output is modeled using the coupling coefficient (K). This coefficient depends on the relationship between the physical length of the coupling region and the beating length:
#
# <img src="k.png" alt="Coupling Coefficient Equation" width="400">
#
# Simulate a directional coupler that implements two deep waveguide cores of thickness 300 nm, 1.2 microns width and with a gap of 600 nm between them.
# - Plot the transfer function: K vs L/Lpi
# - Comment the results: distance needed for a complete energy transfer between waveguides, distance needed for splitting power in half..

# %%
L= np.linspace(0, 300, 100) 
kte=np.sin(np.pi/2*L/L_pi_TE)**2
ktm=np.sin(np.pi/2*L/L_pi_TM)**2

plt.plot(L, kte, label='TE')
plt.plot(L, ktm, label='TM')
plt.xlabel('Length (um)')
plt.ylabel('Coupling Coeff')
plt.legend()

# %% [markdown]
# ## LO.3. 2x2 Directional Coupler
#
# Here, you will use some functions provided by us (check **0. Imports** for more details) to simulate the propagation in a 2x2 (50/50) directional coupler. Please read all the comments in the following code carefully and **make changes only to the lines marked with the #Student tag**

# %%
# Simulation flow for Directional Couplers
# Define your geometrical parameters here
wg_gap = 0.6 # Student. Gap between waveguides
wg_width = 1.2 # Student. Core waveguides width

d = wg_width + wg_gap
wg_N = 2

m = DC_EME() # Here you instantiate a Directional Coupler to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_num_modes = 12 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 
m.DC_wg_gap = wg_gap # Gap between waveguides
m.DC_wg_width = wg_width # Width of the waveguides core
m.DC_N_waveguides = wg_N

# 1) Compute de DC modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  94.02742605180423  µm
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# IMPORTANT!!! 
# # If you DON'T change any geometrical parameter
# (waveguide widths or gap) you can skip last cell. 
# YOU CAN RUN the lines below as many times as you wish
# (SAVES TIME)

# 3) Configure DC
# DC I/O number
m.n_IN = 2
m.n_OUT = 2

m.L_MMI = 0.5*L_pi # Since we use the same library for propagation simulations of MMI and DC 
                    # some variables might be identified as "MMI". Sorry about that (: 
                    # Might change in the future 

# 4) Run propagation - get power transfer and plot propagation
m.propagation()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/940 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 47.0137
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9688
# Total OUT power: 0.9583
# Excess loss [dB] =  0.1851
# ------------------------
# Power over OUTs:  ['0.4791', '0.4791']
# Ratio over OUTs ['0.5000', '0.5000']

# %% [markdown]
# Now sweep gaps between 0.2 and 1.2 µm in steps of 0.2 µm

# %%
# Simulation flow for Directional Couplers
# Define your geometrical parameters here
wg_gap = 0.2 # Student. Gap between waveguides
wg_width = 1.2 # Student. Core waveguides width

d = wg_width + wg_gap
wg_N = 2

m = DC_EME() # Here you instantiate a Directional Coupler to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_num_modes = 12 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 
m.DC_wg_gap = wg_gap # Gap between waveguides
m.DC_wg_width = wg_width # Width of the waveguides core
m.DC_N_waveguides = wg_N

# 1) Compute de DC modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")

# 3) Configure DC
# DC I/O number
m.n_IN = 2
m.n_OUT = 2

m.L_MMI = 0.5*L_pi # Since we use the same library for propagation simulations of MMI and DC 
                    # some variables might be identified as "MMI". Sorry about that (: 
                    # Might change in the future 

# 4) Run propagation - get power transfer and plot propagation
m.propagation()
# Out:
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  25.814236664933663  µm
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 12.9071
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.7802
# Total OUT power: 0.7586
# Excess loss [dB] =  1.2000
# ------------------------
# Power over OUTs:  ['0.3792', '0.3794']
# Ratio over OUTs ['0.4999', '0.5001']

# %%
# Simulation flow for Directional Couplers
# Define your geometrical parameters here
wg_gap = 0.4 # Student. Gap between waveguides
wg_width = 1.2 # Student. Core waveguides width

d = wg_width + wg_gap
wg_N = 2

m = DC_EME() # Here you instantiate a Directional Coupler to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_num_modes = 12 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 
m.DC_wg_gap = wg_gap # Gap between waveguides
m.DC_wg_width = wg_width # Width of the waveguides core
m.DC_N_waveguides = wg_N

# 1) Compute de DC modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")

# 3) Configure DC
# DC I/O number
m.n_IN = 2
m.n_OUT = 2

m.L_MMI = 0.5*L_pi # Since we use the same library for propagation simulations of MMI and DC 
                    # some variables might be identified as "MMI". Sorry about that (: 
                    # Might change in the future 

# 4) Run propagation - get power transfer and plot propagation
m.propagation()
# Out:
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  50.10994896216798  µm
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 25.0550
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.8983
# Total OUT power: 0.8863
# Excess loss [dB] =  0.5243
# ------------------------
# Power over OUTs:  ['0.4433', '0.4430']
# Ratio over OUTs ['0.5001', '0.4999']

# %%
# Simulation flow for Directional Couplers
# Define your geometrical parameters here
wg_gap = 0.8 # Student. Gap between waveguides
wg_width = 1.2 # Student. Core waveguides width

d = wg_width + wg_gap
wg_N = 2

m = DC_EME() # Here you instantiate a Directional Coupler to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_num_modes = 12 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 
m.DC_wg_gap = wg_gap # Gap between waveguides
m.DC_wg_width = wg_width # Width of the waveguides core
m.DC_N_waveguides = wg_N

# 1) Compute de DC modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")

# 3) Configure DC
# DC I/O number
m.n_IN = 2
m.n_OUT = 2

m.L_MMI = 0.5*L_pi # Since we use the same library for propagation simulations of MMI and DC 
                    # some variables might be identified as "MMI". Sorry about that (: 
                    # Might change in the future 

# 4) Run propagation - get power transfer and plot propagation
m.propagation()
# Out:
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  173.9638997714356  µm
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/1740 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 86.9819
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9882
# Total OUT power: 0.9778
# Excess loss [dB] =  0.0976
# ------------------------
# Power over OUTs:  ['0.4888', '0.4890']
# Ratio over OUTs ['0.4999', '0.5001']

# %%
# Simulation flow for Directional Couplers
# Define your geometrical parameters here
wg_gap = 1.0 # Student. Gap between waveguides
wg_width = 1.2 # Student. Core waveguides width

d = wg_width + wg_gap
wg_N = 2

m = DC_EME() # Here you instantiate a Directional Coupler to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_num_modes = 12 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 
m.DC_wg_gap = wg_gap # Gap between waveguides
m.DC_wg_width = wg_width # Width of the waveguides core
m.DC_N_waveguides = wg_N

# 1) Compute de DC modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")

# 3) Configure DC
# DC I/O number
m.n_IN = 2
m.n_OUT = 2

m.L_MMI = 0.5*L_pi # Since we use the same library for propagation simulations of MMI and DC 
                    # some variables might be identified as "MMI". Sorry about that (: 
                    # Might change in the future 

# 4) Run propagation - get power transfer and plot propagation
m.propagation()
# Out:
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  318.884152076578  µm
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/3189 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 159.4421
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9663
# Total OUT power: 0.9560
# Excess loss [dB] =  0.1955
# ------------------------
# Power over OUTs:  ['0.4778', '0.4782']
# Ratio over OUTs ['0.4998', '0.5002']

# %%
# Simulation flow for Directional Couplers
# Define your geometrical parameters here
wg_gap = 1.2 # Student. Gap between waveguides
wg_width = 1.2 # Student. Core waveguides width

d = wg_width + wg_gap
wg_N = 2

m = DC_EME() # Here you instantiate a Directional Coupler to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_num_modes = 12 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 
m.DC_wg_gap = wg_gap # Gap between waveguides
m.DC_wg_width = wg_width # Width of the waveguides core
m.DC_N_waveguides = wg_N

# 1) Compute de DC modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")

# 3) Configure DC
# DC I/O number
m.n_IN = 2
m.n_OUT = 2

m.L_MMI = 0.5*L_pi # Since we use the same library for propagation simulations of MMI and DC 
                    # some variables might be identified as "MMI". Sorry about that (: 
                    # Might change in the future 

# 4) Run propagation - get power transfer and plot propagation
m.propagation()
# Out:
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  580.4293623068716  µm
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/5804 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 290.2147
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.8916
# Total OUT power: 0.8818
# Excess loss [dB] =  0.5464
# ------------------------
# Power over OUTs:  ['0.4407', '0.4410']
# Ratio over OUTs ['0.4998', '0.5002']

# %% [markdown]
# ## LO.4. Parallel uncoupled waveguides
#
# Parallel waveguides always exhibit some evanescent coupling. In this exercise, the goal is to control coupling so that adjacent waveguides remain effectively uncoupled. Define an uncoupled pair as one with coupling coefficient K < 0.01. Assume a parallel interaction length of L = 10 mm (typical chip length). For both shallow-etched and deep-etched waveguides, compute the minimum waveguide gap that satisfies this condition for the **TE0** mode, using w = 1.0 um and lambda = 1.55 um.

# %%
# HINT. Calculate manually the L_pi you may need to achieve K=0.01
# Then you can sweep the gap and calculate the L_pi until reaching 
# the desired value. 
L=10 * 1e3  # Length in meters
k=0.01

L_pi_deseada = (L*np.pi)/(np.arcsin(np.sqrt(k))*2)
print(L_pi_deseada)

lambda_c = 1.55

dcoupler_cs = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(1, 1), # Waveguide width
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness=300 * nm, # Waveguide height 
    gap=3679.03* nm,
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)

dcoupler_cs_shallow = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(1, 1), # Waveguide width
    slab_thickness=150 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness=300 * nm, # Waveguide height 
    gap=3679.03* nm,
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)


Lpifinal_deep=dcoupler_cs.coupling_length()[0]
Lpifinal_shallow=dcoupler_cs_shallow.coupling_length()[0]

print(Lpifinal_deep,Lpifinal_shallow)
# Out:
# 156817.08768975522
# 2026-04-28 13:30:19.204 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_636adb59d59bc33b.npz.
# 2026-04-28 13:30:19.208 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c4fe9ea33d14b60d.npz.
# 156819.65308017185 14607.027839067401

# %%
gap=np.linspace(2.5, 5.5, 50)
coupling_lengths_modos=gt.modes.sweep_coupling_length(dcoupler_cs,np.linspace(2500 *nm, 5500 * nm, 50))
coupling_lengths = coupling_lengths_modos[:, 0]
k=(np.sin((np.pi/2)*(L/coupling_lengths))**2)
plt.plot(gap, k, label='TE')
plt.axhline(y=0.01,linestyle='--',color='r',label='K=0.01')
plt.xlabel('gap (um)')
plt.ylabel('K')
plt.legend()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 2026-04-28 13:40:51.306 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_87641d4cdc9dd751.npz.
# 2026-04-28 13:40:51.310 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e4634329e9742cb0.npz.
# 2026-04-28 13:40:51.315 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4c825ba79d757d87.npz.
# 2026-04-28 13:40:51.319 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4f071a4823536cc4.npz.
# 2026-04-28 13:40:51.321 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_db4e67be73b591ee.npz.
# 2026-04-28 13:40:51.326 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_94ebfcb4d37057c0.npz.
# 2026-04-28 13:40:51.329 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b589cb06f13adb62.npz.
# 2026-04-28 13:40:51.330 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6bd8397ecff9435f.npz.
# 2026-04-28 13:40:51.337 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b110a3670e39d28e.npz.
# 2026-04-28 13:40:51.342 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2a53099d2933a473.npz.
# 2026-04-28 13:40:51.347 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bdb6d82f93eee076.npz.
# 2026-04-28 13:40:51.349 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_75a9a11a008e462e.npz.
# 2026-04-28 13:40:51.350 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bc115ca64d48ba12.npz.
# 2026-04-28 13:40:51.356 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_71f2058fdb909393.npz.
# 2026-04-28 13:40:51.361 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4d09b255baa3c60a.npz.
# 2026-04-28 13:40:51.365 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_644d0e35337f5e10.npz.
# 2026-04-28 13:40:51.369 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bc41c5ded04781bc.npz.
# 2026-04-28 13:40:51.372 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9a83471fc5edc9f4.npz.
# 2026-04-28 13:40:51.377 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f7effeb184130d58.npz.
# 2026-04-28 13:40:51.379 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2cabc2a79a0b8dd4.npz.
# 2026-04-28 13:40:51.384 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b695af3c084afe80.npz.
# 2026-04-28 13:40:51.390 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bec6c8da65e92810.npz.
# 2026-04-28 13:40:51.394 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bafcdfc75d2d1383.npz.
# 2026-04-28 13:40:51.397 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ab9515a10357355d.npz.
# 2026-04-28 13:40:51.400 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ce55f16b0812477e.npz.
# 2026-04-28 13:40:51.406 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fe6302d15758ed30.npz.
# 2026-04-28 13:40:51.412 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_13f04aafedbddfe2.npz.
# 2026-04-28 13:40:51.414 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4b8d0bdb93cae9c3.npz.
# 2026-04-28 13:40:51.419 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_207bdf1c72b3c6d2.npz.
# 2026-04-28 13:40:51.423 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_17dc3b560351e315.npz.
# 2026-04-28 13:40:51.428 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_1e5a5e7ff3c224fd.npz.
# 2026-04-28 13:40:51.432 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b256be6f1c1d599f.npz.
# 2026-04-28 13:40:51.436 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_294088f915d8d0b3.npz.
# 2026-04-28 13:40:51.441 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_67b3f9e1733d7399.npz.
# 2026-04-28 13:40:51.446 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4b9bd21f692beb26.npz.
# 2026-04-28 13:40:51.450 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fdb958d2dbe1bd14.npz.
# 2026-04-28 13:40:51.454 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6c95bfc6f4f05555.npz.
# 2026-04-28 13:40:51.459 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ac2292c935e8358e.npz.
# 2026-04-28 13:40:51.463 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5776726914902ad8.npz.
# 2026-04-28 13:40:51.466 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_927a9f9befc073a4.npz.
# 2026-04-28 13:40:51.470 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_eb8b79baa033d19d.npz.
# 2026-04-28 13:40:51.474 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c5c93ba4accce906.npz.
# 2026-04-28 13:40:51.478 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c1394837416aebfa.npz.
# 2026-04-28 13:40:51.484 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_def3c29e6e8e5e8b.npz.
# 2026-04-28 13:40:51.488 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ee05ba95b4a62aa2.npz.
# 2026-04-28 13:40:51.491 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fc1155af34799439.npz.
# 2026-04-28 13:40:51.496 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4b8031ec5a0aaa7e.npz.
# 2026-04-28 13:40:51.500 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4d82ccbb35d0bbea.npz.
# 2026-04-28 13:40:51.503 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_dfafc7cfefd4202f.npz.
# 2026-04-28 13:40:51.507 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c71a11a14657a88d.npz.

# %%
gap=np.linspace(2.5, 5.5, 50)
coupling_lengths_modos=gt.modes.sweep_coupling_length(dcoupler_cs_shallow,np.linspace(2500 *nm, 5500 * nm, 50))
coupling_lengths = coupling_lengths_modos[:, 0]
k=(np.sin((np.pi/2)*(L/coupling_lengths))**2)
plt.plot(gap, k, label='TE')
plt.axhline(y=0.01,linestyle='--',color='r',label='K=0.01')
plt.xlabel('gap (um)')
plt.ylabel('K')
plt.legend()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 2026-04-28 13:41:14.260 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_804e6ebd40f61ba8.npz.
# 2026-04-28 13:41:14.264 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9423f77e4f1a60b7.npz.
# 2026-04-28 13:41:14.270 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2823293f9616cf65.npz.
# 2026-04-28 13:41:14.273 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_1de615bd8c10994e.npz.
# 2026-04-28 13:41:14.276 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e44c9747cec5af43.npz.
# 2026-04-28 13:41:14.279 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_70243c4aada98161.npz.
# 2026-04-28 13:41:14.283 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_45b0c2dfae044fa0.npz.
# 2026-04-28 13:41:14.286 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d1fbb20ff4ed568c.npz.
# 2026-04-28 13:41:14.292 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c0e7e27017798f5a.npz.
# 2026-04-28 13:41:14.294 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0b725339efe0ee85.npz.
# 2026-04-28 13:41:14.298 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_672e26d77d07ecf3.npz.
# 2026-04-28 13:41:14.301 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d43bbea64500a428.npz.
# 2026-04-28 13:41:14.305 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_46e8d2151077482d.npz.
# 2026-04-28 13:41:14.308 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_82cfd90de3985778.npz.
# 2026-04-28 13:41:14.312 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_423631a8f610115c.npz.
# 2026-04-28 13:41:14.315 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8f638d7ea5c2753a.npz.
# 2026-04-28 13:41:14.318 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_09f680bef08517c0.npz.
# 2026-04-28 13:41:14.323 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5a0cb9e60dc5a3fa.npz.
# 2026-04-28 13:41:14.327 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b326668df59caf11.npz.
# 2026-04-28 13:41:14.332 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f594715887b2ba0b.npz.
# 2026-04-28 13:41:14.334 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a7b136f0978ea548.npz.
# 2026-04-28 13:41:14.337 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_217692f0534a8f3c.npz.
# 2026-04-28 13:41:14.343 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cdbb8794591cecf2.npz.
# 2026-04-28 13:41:14.347 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e98592e9e51b8888.npz.
# 2026-04-28 13:41:14.351 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_1b197b7bd2ad6ec9.npz.
# 2026-04-28 13:41:14.356 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7e525e5d37e8e927.npz.
# 2026-04-28 13:41:14.363 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a140b6f526b81edd.npz.
# 2026-04-28 13:41:14.367 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fd134ce25e65241c.npz.
# 2026-04-28 13:41:14.371 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9aa60a642a372e37.npz.
# 2026-04-28 13:41:14.376 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c09a61b9237f9cab.npz.
# 2026-04-28 13:41:14.379 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_3e080d166c151aad.npz.
# 2026-04-28 13:41:14.383 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f4884591a4cdb209.npz.
# 2026-04-28 13:41:14.388 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a36823161d067192.npz.
# 2026-04-28 13:41:14.393 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5ae4a4c4a8475e22.npz.
# 2026-04-28 13:41:14.396 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bfd954c4dd255546.npz.
# 2026-04-28 13:41:14.401 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0138db648f3536e9.npz.
# 2026-04-28 13:41:14.404 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a95572160b21c824.npz.
# 2026-04-28 13:41:14.409 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_976d8ff658b3402b.npz.
# 2026-04-28 13:41:14.412 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_93c3a932fca2fb2f.npz.
# 2026-04-28 13:41:14.415 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e63e1a6dca957fea.npz.
# 2026-04-28 13:41:14.421 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c74d965524005d6c.npz.
# 2026-04-28 13:41:14.426 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0b445c3e669910ae.npz.
# 2026-04-28 13:41:14.433 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a02331b980dcc375.npz.
# 2026-04-28 13:41:14.439 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_3eea0609c0056685.npz.
# 2026-04-28 13:41:14.445 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6f2eca61f8091cd4.npz.
# 2026-04-28 13:41:14.448 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9f2ff632f7fd48ed.npz.
# 2026-04-28 13:41:14.453 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_511c379a6a8af676.npz.
# 2026-04-28 13:41:14.459 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_3d51db653dc3cc1a.npz.
# 2026-04-28 13:41:14.462 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e1ac5725e87446ec.npz.
# 2026-04-28 13:41:14.466 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2dcd340ef49a7706.npz.

# %% [markdown]
# ## LO.5. Multimode Interference (MMI) Coupler cross-section
#
# ### LO.5.1. Cross-Section definition and simulation
#
# In GDSFactory - Tidy3d modesolver, we can simulate the Cross-Section of a multimode interference coupler using the previously studied : [gt.modes.Waveguide()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.Waveguide.html) function. The parameters will correspond to the dimensions of the MMI body section.

# %%
mmi_body_w = 12  
lambda_c = 1550*nm

mmi_body_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=mmi_body_w, # MMI Body width
    core_thickness=300 * nm, # MMI Body height 
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=20, # Targeted number of modes to find - Higher than before! It's a multimode section
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

mmi_body_waveguide.n_eff
# Out:
# 2026-04-28 12:23:51.444 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6c30818797bb0c38.npz.
# array([1.6786595 +7.78934672e-05j, 1.67512732+7.81571827e-05j,
#        1.66922847+7.86028340e-05j, 1.66094525+7.92401466e-05j,
#        1.65025312+8.00839409e-05j, 1.63712124+8.11557006e-05j,
#        1.6215135 +8.24863265e-05j, 1.60339058+8.41212350e-05j,
#        1.58271457+8.61311110e-05j, 1.5774205 +1.66068730e-04j,
#        1.57388942+1.66498915e-04j, 1.56799588+1.67223410e-04j,
#        1.55972723+1.68258132e-04j, 1.5594584 +8.86366882e-05j,
#        1.54906903+1.69617736e-04j, 1.53601168+1.71243999e-04j,
#        1.53362692+9.19569893e-05j, 1.52054265+1.73463904e-04j,
#        1.5053405 +9.64080926e-05j, 1.50269423+1.76086361e-04j])

# %%
mmi_body_waveguide.fraction_te
# Out:
# array([9.99991904e-01, 9.99967183e-01, 9.99924497e-01, 9.99861445e-01,
#        9.99774272e-01, 9.99657368e-01, 9.99502382e-01, 9.99296461e-01,
#        9.99013009e-01, 2.38565216e-04, 9.55099424e-04, 2.13831793e-03,
#        3.73633926e-03, 9.98594348e-01, 5.78997522e-03, 9.32192912e-03,
#        9.96954269e-01, 1.09103635e-02, 9.97247761e-01, 1.38536938e-02])

# %%
mmi_body_waveguide.plot_field(mode_index=0 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)
) #

# %%
mmi_body_waveguide.plot_field(mode_index=1 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
mmi_body_waveguide.plot_field(mode_index=7, # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %% [markdown]
# #### LO.5.2 Length calculation (𝐿𝜋)
#
# With this information, we could calculate our first guess for the 𝐿𝜋 length of the MMI coupler:

# %%
d_n_eff = mmi_body_waveguide.n_eff[0].real -  mmi_body_waveguide.n_eff[1].real

L_pi = 0.5*lambda_c/(d_n_eff)

print (L_pi)
# Out:
# 219.41119794414357

# %% [markdown]
# ## LO.6. 2x2 Multimode Interference Coupler
#
# ### LO.6.1 Propagation Simulation

# %% [markdown]
# For the multimode interference (MMI) couplers we must rely on the design tables shown on the theoretical session:
#
# <img src="mmi.png" alt="Design tables for MMI couplers" width="600">
#
# Here, you will use some functions provided by us (check **0. Imports** for more details) to simulate the propagation in a 2x2 directional coupler. Please read all the comments in the following code carefully and **make changes only to the lines marked with the #Student tag**

# %%
# Simulation flow for MMI Couplers
# Define your geometrical parameters here
mmi_Width = 6.6 # Student. Body width

m = MMI_EME() # Here you instantiate a MMI to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_width = mmi_Width
m.MMI_num_modes = 20 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 

# 1) Compute de MMI body modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  69.03598607256687  µm
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# IMPORTANT!!! 
# # If you DON'T change neither the MMI width 
# nor input/output waveguide widths
# YOU CAN RUN the lines below as many times as you wish
# (SAVES TIME)

# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)
m.n_IN =  2 # STUDENT
m.n_OUT = 2 # STUDENT

# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) # STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = (1/2)*L_pi # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/690 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9604
# Total OUT power: 0.9075
# Excess loss [dB] =  0.4217
# ------------------------
# Power over OUTs:  ['0.4675', '0.4399']
# Ratio over OUTs ['0.5152', '0.4848']

# %% [markdown]
# ### LO.6.2. 2x2 Multimode Interference Coupler - Optimization

# %%
dy = 0.05
# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy])  # STUDENT

# MMI length (check class slides for type of MMI)
m.dL_MMI = -0.3 # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/684 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment -0.3000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9571
# Total OUT power: 0.9162
# Excess loss [dB] =  0.3800
# ------------------------
# Power over OUTs:  ['0.4670', '0.4492']
# Ratio over OUTs ['0.5097', '0.4903']

# %% [markdown]
# ### LO.6.3 2x2 Multimode Interference Coupler – Optimization (II)

# %%
# Design flow for MMI

m = MMI_EME()
m.MMI_width = 6.6   # MMI width
m.wg_width_dw = 0.8 # STUDENT

# 1) Compute de MMI modes
m.find_all_modes()

# 2) Get the L_pi
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  69.0359860725737  µm
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)
m.n_IN = 2 # STUDENT
m.n_OUT = 2 # STUDENT

dy = 0.02
# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy])  # STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = (1/2)*L_pi  # STUDENT
m.dL_MMI = 0.36 # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/698 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment 0.3600
# IO wg width 1.0000
# IO wg width increment 0.8000
# ------------------------
# Total power IN coupled 0.9960
# Total OUT power: 0.9773
# Excess loss [dB] =  0.0997
# ------------------------
# Power over OUTs:  ['0.4887', '0.4886']
# Ratio over OUTs ['0.5000', '0.5000']

# %% [markdown]
# ## LO.7. 1x4 Multimode Interference Coupler
#
# Repeat the design procedure explained for the 2x2 Coupler to design a 1x4 MMI Coupler. Consider:
# - Select a suitable MMI body width, taking into account that you now must allocate 4 waveguides at the output.
# - Minimize the losses and output imbalance for the MMI coupler.

# %%
# Simulation flow for MMI Couplers
# Define your geometrical parameters here
mmi_Width = 12 # Student. Body width

m = MMI_EME() # Here you instantiate a MMI to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_width = mmi_Width
m.MMI_num_modes = 20 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition.

m.wg_width_dw = 0.8 # STUDENT

# 1) Compute de MMI modes
m.find_all_modes()

# 2) Get the L_pi
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")

# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)
m.n_IN = 1 # STUDENT
m.n_OUT = 4 # STUDENT
# Out:
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  219.13931544098588  µm
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
dy = -0.1
# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([0]) + np.array([dy]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-2.4/6,-0.85/6,0.85/6,2.4/6]) + np.array([-dy,-dy,dy,dy])  # STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = (3/16)*L_pi  # STUDENT
m.dL_MMI = -0.5 # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/812 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 41.0886
# MMI length increment -0.5000
# IO wg width 1.0000
# IO wg width increment 0.8000
# ------------------------
# Total power IN coupled 0.9877
# Total OUT power: 0.9614
# Excess loss [dB] =  0.1710
# ------------------------
# Power over OUTs:  ['0.2441', '0.2489', '0.2427', '0.2257']
# Ratio over OUTs ['0.2539', '0.2589', '0.2524', '0.2347']

# %% [markdown]
# ## Extra - Exercises

# %% [markdown]
# ### E1. Directional coupler gap dependence

# %%
lambda_c = 1.55

dcoupler_cs = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(1, 1), # Waveguide width
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness=300 * nm, # Waveguide height 
    gap=3679.03* nm,
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)

dcoupler_cs_shallow = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(1, 1), # Waveguide width
    slab_thickness=150 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness=300 * nm, # Waveguide height 
    gap=3679.03* nm,
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)


# STUDENT. Plot goes here

#Deep
gap=np.arange(0.2, 2.6, 0.2)
coupling_lengths_modos=gt.modes.sweep_coupling_length(dcoupler_cs,np.arange(0.2, 2.6, 0.2))
coupling_lengths_TE = coupling_lengths_modos[:, 0]
coupling_lengths_TM = coupling_lengths_modos[:, 1]

plt.title("L_pi vs gap for deep guide Coupler")
plt.plot(gap, coupling_lengths_TE, label='Deep TE')
plt.plot(gap, coupling_lengths_TM, label='Deep TM')
plt.scatter(gap, coupling_lengths_TE,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.scatter(gap, coupling_lengths_TM,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.xlabel('gap (um)')
plt.ylabel('Lpi (um)')
plt.legend()
plt.grid()
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 2026-05-04 01:27:41.324 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_19fc40f5ad5a09a8.npz.
# 2026-05-04 01:27:41.336 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_266d67620f0948f9.npz.
# 2026-05-04 01:27:41.340 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fa4c4babd472f540.npz.
# 2026-05-04 01:27:41.344 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f8167db7728a9ebb.npz.
# 2026-05-04 01:27:41.353 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b0f701e58db4a1bf.npz.
# 2026-05-04 01:27:41.358 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_de78bc7bac7ad149.npz.
# 2026-05-04 01:27:41.363 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_69d8430ee5b848c9.npz.
# 2026-05-04 01:27:41.369 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ce577367a47a40cf.npz.
# 2026-05-04 01:27:41.373 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_51919864b2bb47b4.npz.
# 2026-05-04 01:27:41.377 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8e0bd02e52bb6fea.npz.
# 2026-05-04 01:27:41.382 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cbd4017b74156e86.npz.
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-05-04 01:27:43.716 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/WaveguideCoupler_186b33d829047bed.npz.

# %%
#Shallow
gap=np.arange(0.2, 2.6, 0.2)
coupling_lengths_modos=gt.modes.sweep_coupling_length(dcoupler_cs_shallow,np.arange(0.2, 2.6, 0.2))
coupling_lengths_TE = coupling_lengths_modos[:, 0]
coupling_lengths_TM = coupling_lengths_modos[:, 1]
plt.title("L_pi vs gap for Shallow guide Coupler")
plt.plot(gap, coupling_lengths_TE, label='Shallow TE')
plt.plot(gap, coupling_lengths_TM, label='Shallow TM')
plt.scatter(gap, coupling_lengths_TE,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.scatter(gap, coupling_lengths_TM,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.xlabel('gap (um)')
plt.ylabel('Lpi (um)')
plt.ylim(0, 2000)
plt.legend()
plt.grid()
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 2026-05-04 01:29:36.469 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8c8eb63846dcafc2.npz.
# 2026-05-04 01:29:36.475 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9f55a49562c957ac.npz.
# 2026-05-04 01:29:36.479 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0aace39711989615.npz.
# 2026-05-04 01:29:36.482 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_469dd463acb1cce2.npz.
# 2026-05-04 01:29:36.485 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_12053cc304837a1c.npz.
# 2026-05-04 01:29:36.490 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_64ce3e0adbff4874.npz.
# 2026-05-04 01:29:36.492 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9664102640d36134.npz.
# 2026-05-04 01:29:36.494 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a7be85a5f0c2c3ff.npz.
# 2026-05-04 01:29:36.505 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_619b4739561083d3.npz.
# 2026-05-04 01:29:36.509 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9983c5c8ec0df30b.npz.
# 2026-05-04 01:29:36.514 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_295e702940328765.npz.
# 2026-05-04 01:29:36.518 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2d34b91294a1c485.npz.

# %% [markdown]
# ### E2. Directional coupler wavelength dependence

# %%
wavelength = np.linspace(1.5, 1.7, 50)  # STUDENT code goes here

deep_dcoupler_cs = gt.modes.WaveguideCoupler(
    wavelength=wavelength, # Wavelength to simulate - Must be a vector
    core_width=(1.0, 1.0), # Waveguide width
    gap=600 * nm,
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    core_thickness=300 * nm, # Waveguide height 
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)

deep_neff = deep_dcoupler_cs.n_eff


n_even_TE = deep_neff[:,0]
n_odd_TE  = deep_neff[:,1]

n_even_TM = deep_neff[:,2]
n_odd_TM  = deep_neff[:,3]

# Longitud de acoplo
L_pi_TM = wavelength / (2 * (n_even_TM - n_odd_TM))
L_pi_TE = wavelength / (2 * (n_even_TE - n_odd_TE))

plt.figure(figsize=(10, 5))
plt.title("L_pi vs Wavelength for deep guide Coupler")
plt.scatter(wavelength, L_pi_TE,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.scatter(wavelength, L_pi_TM,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.plot(wavelength, L_pi_TE,label='TE mode')
plt.plot(wavelength, L_pi_TM,label='TM mode')
plt.xlabel("Wavelength (um)")
plt.ylabel("L_pi (um)")
plt.grid()
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout(rect=[0, 0, 0.85, 1])
# Out:
# 2026-05-04 00:53:41.070 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_87184d92a4b79ac2.npz.
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/matplotlib/collections.py:200: ComplexWarning: Casting complex values to real discards the imaginary part
#   offsets = np.asanyarray(offsets, float)
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
wavelength = np.linspace(1.5, 1.7, 50)  # STUDENT code goes here

shallow_dcoupler_cs = gt.modes.WaveguideCoupler(
    wavelength=wavelength, # Wavelength to simulate - Must be a vector
    core_width=(1.0, 1.0), # Waveguide width
    gap=600 * nm,
    slab_thickness=150 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    core_thickness=300 * nm, # Waveguide height 
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)

shallow_neff = shallow_dcoupler_cs.n_eff


n_even_TE = shallow_neff[:,0]
n_odd_TE  = shallow_neff[:,1]

n_even_TM = shallow_neff[:,2]
n_odd_TM  = shallow_neff[:,3]

# Longitud de acoplo
L_pi_TM = wavelength / (2 * (n_even_TM - n_odd_TM))
L_pi_TE = wavelength / (2 * (n_even_TE - n_odd_TE))

plt.figure(figsize=(10, 5))
plt.title("L_pi vs Wavelength for Shallow guide Coupler")
plt.scatter(wavelength, L_pi_TE,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.scatter(wavelength, L_pi_TM,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.plot(wavelength, L_pi_TE,label='TE mode')
plt.plot(wavelength, L_pi_TM,label='TM mode')
plt.xlabel("Wavelength (um)")
plt.ylabel("L_pi(um)")
plt.grid()
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout(rect=[0, 0, 0.85, 1])
# Out:
# 2026-05-04 00:53:45.427 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4344678acf7246bb.npz.

# %% [markdown]
# ### E3. MMI coupler wavelength dependence

# %%
mmi_body_w = 6.6 
lambda_c = np.linspace(1.5, 1.7, 10) # STUDENT code goes here.

mmi_body_waveguide_deep = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=mmi_body_w, # MMI Body width
    core_thickness=300 * nm, # MMI Body height 
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=15, # Targeted number of modes to find - Higher than before! It's a multimode section
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

d_n_eff_TE = mmi_body_waveguide_deep.n_eff[:,0].real -  mmi_body_waveguide_deep.n_eff[:,1].real
L_pi_TE = lambda_c / (2 * d_n_eff_TE)

d_n_eff_TM = ( mmi_body_waveguide_deep.n_eff[:,2].real - mmi_body_waveguide_deep.n_eff[:,3].real)
L_pi_TM = lambda_c / (2 * d_n_eff_TM)

plt.title("L_pi vs Wavelength deep coupler for MMI Body")
plt.plot(lambda_c, L_pi_TE, label='TE')
plt.plot(lambda_c, L_pi_TM, label='TM')
plt.scatter(lambda_c, L_pi_TE,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.scatter(lambda_c, L_pi_TM,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.xlabel('Wavelength (um)')
plt.ylabel('Lpi (um)')

plt.legend()
plt.grid()

plt.show()
# STUDENT plot here.
# Out:
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 01:03:12 CEST WARNING: Mode '12' appears to undergo a discontinuous change
#               between frequencies '191356888085106.38' and '188680567972027.97'
#               (overlap: '0.87').
#               WARNING: Mode '14' appears to undergo a discontinuous change
#               between frequencies '191356888085106.38' and '188680567972027.97'
#               (overlap: '0.87').
#               WARNING: Mode '12' appears to undergo a discontinuous change
#               between frequencies '194110224604316.53' and '191356888085106.38'
#               (overlap: '0.70').
#               WARNING: Mode '14' appears to undergo a discontinuous change
#               between frequencies '194110224604316.53' and '191356888085106.38'
#               (overlap: '0.71').
# 01:03:13 CEST WARNING: Mode '14' appears to undergo a discontinuous change
#               between frequencies '183546402857142.88' and '186078077379310.34'
#               (overlap: '0.00').
#               WARNING: Mode '13' appears to undergo a discontinuous change
#               between frequencies '176348504705882.34' and '178684246490066.22'
#               (overlap: '0.00').
# 01:03:14 CEST WARNING: Mode field at frequency index 0, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 1, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 2, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 3, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 3, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 4, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 4, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 5, mode index 12 does not
#               decay at the plane boundaries.
# 01:03:15 CEST WARNING: Mode field at frequency index 5, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 6, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 6, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 7, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 7, mode index 13 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 7, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 8, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 8, mode index 13 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 8, mode index 14 does not
#               decay at the plane boundaries.
# 01:03:16 CEST WARNING: Mode field at frequency index 9, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 9, mode index 13 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 9, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: The group index was not computed. To calculate group
#               index, pass 'group_index_step = True' in the 'ModeSpec'.
# 2026-05-04 01:03:16.591 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_af351e083836ee20.npz.

# %%
mmi_body_w = 6.6 
lambda_c = np.linspace(1.5, 1.7, 10) # STUDENT code goes here.

mmi_body_waveguide_shallow = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=mmi_body_w, # MMI Body width
    core_thickness=300 * nm, # MMI Body height 
    slab_thickness=150 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=15, # Targeted number of modes to find - Higher than before! It's a multimode section
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

d_n_eff_TE = mmi_body_waveguide_shallow.n_eff[:,0].real -  mmi_body_waveguide_shallow.n_eff[:,1].real
L_pi_TE = lambda_c / (2 * d_n_eff_TE)

d_n_eff_TM = ( mmi_body_waveguide_shallow.n_eff[:,2].real - mmi_body_waveguide_shallow.n_eff[:,3].real)
L_pi_TM = lambda_c / (2 * d_n_eff_TM)

plt.title("L_pi vs Wavelength shallow coupler for MMI Body")
plt.plot(lambda_c, L_pi_TE, label='TE')
plt.plot(lambda_c, L_pi_TM, label='TM')
plt.scatter(lambda_c, L_pi_TE,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.scatter(lambda_c, L_pi_TM,edgecolors='k',facecolors='none',label = '__nolegend__')
plt.xlabel('Wavelength (um)')
plt.ylabel('Lpi (um)')

plt.legend()
plt.grid(True)

plt.show()
# STUDENT plot here.
# Out:
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/ainap/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 01:04:24 CEST WARNING: Mode '14' appears to undergo a discontinuous change
#               between frequencies '188680567972027.97' and '186078077379310.34'
#               (overlap: '0.00').
# 01:04:26 CEST WARNING: Mode field at frequency index 0, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 1, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 1, mode index 10 does not
#               decay at the plane boundaries.
# 01:04:27 CEST WARNING: Mode field at frequency index 1, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 1, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 2, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 2, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 2, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 2, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 3, mode index 9 does not
#               decay at the plane boundaries.
# 01:04:28 CEST WARNING: Mode field at frequency index 3, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 3, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 3, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 4, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 4, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 4, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 4, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 5, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 5, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 5, mode index 12 does not
#               decay at the plane boundaries.
# 01:04:29 CEST WARNING: Mode field at frequency index 6, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 6, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 6, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 7, mode index 7 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 7, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 7, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 7, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 8, mode index 7 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 8, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 8, mode index 10 does not
#               decay at the plane boundaries.
# 01:04:30 CEST WARNING: Mode field at frequency index 8, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 9, mode index 7 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 9, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 9, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 9, mode index 12 does not
#               decay at the plane boundaries.
# 2026-05-04 01:04:31.636 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_fe57688927a5a05a.npz.

# %% [markdown]
# ### E4. MMI coupler body width dependence

# %%
lambda_c = 1.55

mmi_body_w = np.arange(5, 10.5, 0.5)

Lpi_TE_vals = []
Lpi_TM_vals = []

for w in mmi_body_w:

    mmi_body_waveguide_deep = gt.modes.Waveguide(
        core_width=w,
        core_thickness=300 * nm,
        slab_thickness=0 * nm,

        core_material='sin',
        clad_material='sio2',

        wavelength=lambda_c,
        num_modes=6,
        max_grid_scaling=1.5,
        grid_resolution=15,
        cache_path='.cache/',
        precision='double',
    )

  
    d_n_eff_TE = ( mmi_body_waveguide_deep.n_eff[0].real - mmi_body_waveguide_deep.n_eff[1].real)
    d_n_eff_TM = ( mmi_body_waveguide_deep.n_eff[2].real - mmi_body_waveguide_deep.n_eff[3].real)

    L_pi_TM = lambda_c / (2 * d_n_eff_TM)
    L_pi_TE = lambda_c / (2 * d_n_eff_TE)

    Lpi_TE_vals.append(L_pi_TE)
    Lpi_TM_vals.append(L_pi_TM)

plt.plot(mmi_body_w, Lpi_TE_vals, marker='o', label='TE')
plt.plot(mmi_body_w, Lpi_TM_vals, marker='s', label='TM')
plt.title("L_pi vs MMI width for deep MMI Coupler")
plt.xlabel("MMI width (µm)")
plt.ylabel("Lpi (µm)")
plt.grid()
plt.legend()

plt.show() # STUDENT code goes here

# STUDENT plot here.
# Out:
# 2026-05-04 01:24:54.733 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5bd8b7989aca2ee7.npz.
# 2026-05-04 01:24:54.739 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_19b116bef4f59752.npz.
# 2026-05-04 01:24:54.743 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_0301cb37f3c51500.npz.
# 2026-05-04 01:24:54.753 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_379f3072e825c16d.npz.
# 2026-05-04 01:24:54.756 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_fae27728e2c1232c.npz.
# 2026-05-04 01:24:54.761 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_46f12da73246e4a2.npz.
# 2026-05-04 01:24:54.766 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ec9aad1ef82493ee.npz.
# 2026-05-04 01:24:54.774 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_677093110f42c102.npz.
# 2026-05-04 01:24:54.778 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6a4323b30f20c1da.npz.
# 2026-05-04 01:24:54.780 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_3a993443e5e85272.npz.
# 2026-05-04 01:24:54.782 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_2b37b6949c0a7673.npz.

# %%
lambda_c = 1.55

mmi_body_w = np.arange(5, 10.5, 0.5)

Lpi_TE_vals = []
Lpi_TM_vals = []

for w in mmi_body_w:

    mmi_body_waveguide_shallow = gt.modes.Waveguide(
        core_width=w,
        core_thickness=300 * nm,
        slab_thickness=150 * nm,

        core_material='sin',
        clad_material='sio2',

        wavelength=lambda_c,
        num_modes=6,
        max_grid_scaling=1.5,
        grid_resolution=15,
        cache_path='.cache/',
        precision='double',
    )

  
    d_n_eff_TE = ( mmi_body_waveguide_shallow.n_eff[0].real - mmi_body_waveguide_shallow.n_eff[1].real)
    d_n_eff_TM = ( mmi_body_waveguide_shallow.n_eff[2].real - mmi_body_waveguide_shallow.n_eff[3].real)

    L_pi_TM = lambda_c / (2 * d_n_eff_TM)
    L_pi_TE = lambda_c / (2 * d_n_eff_TE)

    Lpi_TE_vals.append(L_pi_TE)
    Lpi_TM_vals.append(L_pi_TM)

plt.plot(mmi_body_w, Lpi_TE_vals, marker='o', label='TE')
plt.plot(mmi_body_w, Lpi_TM_vals, marker='s', label='TM')

plt.title("L_pi vs MMI width for shallow MMI Coupler")
plt.xlabel("MMI width (µm)")
plt.ylabel("Lpi (µm)")
plt.grid()
plt.xlim(min(mmi_body_w), max(mmi_body_w) + 0.5)
plt.legend()

plt.show() # STUDENT code goes here
# Out:
# 2026-05-04 01:25:04.214 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_422e5d3b0bc055a5.npz.
# 2026-05-04 01:25:04.225 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5391a2b8556f9123.npz.
# 2026-05-04 01:25:04.228 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_aee11e44c4e0fae5.npz.
# 2026-05-04 01:25:04.238 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_2da5a03451667190.npz.
# 2026-05-04 01:25:04.245 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4541a21a94c1b90c.npz.
# 2026-05-04 01:25:04.249 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_278786d4d6bf5dfe.npz.
# 2026-05-04 01:25:04.253 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_2cbe6b660e474922.npz.
# 2026-05-04 01:25:04.257 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_92b2e17ec966e6c9.npz.
# 2026-05-04 01:25:04.261 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_2626520e6b37665d.npz.
# 2026-05-04 01:25:04.271 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5883c6fc6649e791.npz.
# 2026-05-04 01:25:04.276 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_475677b620e3ca5a.npz.

# %% [markdown]
# # Grading
# - LO1 - 0.5 Point
# - LO2 - 1 Point
# - LO3 - 1 Point
# - LO4 - 1 Point
# - LO5 - 0.5 Point
# - LO6 - 1 Point
# - LO7 - 2 Points
# - E1-E4 - Up to 3 Points
